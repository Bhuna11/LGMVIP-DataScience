# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuna11/LGMVIP-DataScience/blob/main/Task1_LGMVIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
image = cv2.imread("flower.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=239x159 at 0x7FADD4D403D0>

# %%
grey = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey)
# Out:
# <PIL.Image.Image image mode=L size=239x159 at 0x7FADCA069BD0>

# %%
invert = cv2.bitwise_not(grey)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=239x159 at 0x7FADD4D408D0>

# %%
blur = cv2.GaussianBlur(invert, (21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=239x159 at 0x7FADCA079090>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=239x159 at 0x7FADCA079990>

# %%
sketch = cv2.divide(grey,invertblur,scale=255.0)
cv2_imshow(sketch)
cv2.imwrite("flower.jpg",sketch)
# Out:
# <PIL.Image.Image image mode=L size=239x159 at 0x7FADCA079BD0>
# True
